# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout, BatchNormalization, Input, GlobalAveragePooling2D, Normalization
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications import ResNet50

import matplotlib.pyplot as plt

train_data = tf.keras.utils.image_dataset_from_directory(
    directory='/kaggle/input/dogs-vs-cats/train',
    labels='inferred',
    label_mode='int',
    color_mode='rgb',
    batch_size=16,
    image_size=(256, 256),
    shuffle=True,
    seed=123,
    validation_split=0.2,
    subset='training',
    verbose=True,
)

val_data = tf.keras.utils.image_dataset_from_directory(
    directory='/kaggle/input/dogs-vs-cats/train',
    labels='inferred',
    label_mode='int',
    color_mode='rgb',
    batch_size=16,
    image_size=(256, 256),
    shuffle=True,
    seed=123,
    validation_split=0.2,
    subset='validation',
    verbose=True,
)

test_data = tf.keras.utils.image_dataset_from_directory(
    directory='/kaggle/input/dogs-vs-cats/test',
    labels=None,
    color_mode='rgb',
    batch_size=16,
    image_size=(256, 256),
    shuffle=False,
    verbose=True,
)

AUTOTUNE = tf.data.AUTOTUNE
train_data = train_data.cache().prefetch(buffer_size=AUTOTUNE)
val_data = val_data.prefetch(buffer_size=AUTOTUNE)
test_data = test_data.prefetch(buffer_size=AUTOTUNE)

data_augmentation = Sequential([
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(0.2),
    tf.keras.layers.RandomZoom(0.2),
    tf.keras.layers.RandomContrast(0.2),
    tf.keras.layers.RandomTranslation(height_factor=0.1, width_factor=0.1)
])

def build_model():
    base_model = ResNet50(
    weights='imagenet',
    include_top=False,
    input_shape=(256, 256, 3)
    )
    
    base_model.trainable = False
    
    inputs = Input(shape=(256, 256, 3))
    
    normalizer = Normalization(axis=-1)
    normalizer.adapt(train_data.map(lambda x, y: x))
    
    x = normalizer(inputs)
    x = data_augmentation(x)
    x = tf.keras.applications.resnet50.preprocess_input(x)
    x = base_model(x, training=False)
    
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)
    x = Dense(512, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.4)(x)
    x = Dense(128, activation='relu')(x)
    outputs = Dense(1, activation='sigmoid')(x)
    
    return Model(inputs, outputs)

model = build_model()

initial_learning_rate = 0.001
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate,
    decay_steps=train_data.cardinality().numpy() // 2,
    decay_rate=0.9,
    staircase=True
)
optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule)

model.compile(
    optimizer=optimizer,
    loss='binary_crossentropy',
    metrics=[
        'accuracy',
        tf.keras.metrics.AUC(name='auc'),
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
)

callbacks = [
    EarlyStopping(
        monitor='val_loss',
        patience=7,
        restore_best_weights=True,
        verbose=1
    ),
    ModelCheckpoint(
        'best_dog_cat_model_resnet.keras',
        monitor='val_accuracy',
        save_best_only=True,
        mode='max',
        verbose=1
    )
]

print("Phase 1: Training with frozen base model...")
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=15,
    callbacks=callbacks,
    verbose=1
)

print("Phase 2: Fine-tuning the model...")
base_model = model.layers[3]
base_model.trainable = True

for layer in base_model.layers[:250]:
    layer.trainable = False

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
    loss='binary_crossentropy',
    metrics=[
        'accuracy',
        tf.keras.metrics.AUC(name='auc'),
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
)

fine_tune_history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=10,
    callbacks=callbacks,
    verbose=1
)

val_results = model.evaluate(val_data, verbose=1)
print(f"Final Validation Loss: {val_results[0]:.4f}")
print(f"Final Validation Accuracy: {val_results[1]:.4f}")
print(f"Final Validation AUC: {val_results[2]:.4f}")
print(f"Final Validation Precision: {val_results[3]:.4f}")
print(f"Final Validation Recall: {val_results[4]:.4f}")

def plot_training_history(history, fine_tune_history=None):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
    
    epochs_initial = range(1, len(history.history['accuracy']) + 1)
    ax1.plot(epochs_initial, history.history['accuracy'], 'b-', label='Training Accuracy')
    ax1.plot(epochs_initial, history.history['val_accuracy'], 'r-', label='Validation Accuracy')
    
    if fine_tune_history:
        epochs_fine = range(len(history.history['accuracy']) + 1, 
                          len(history.history['accuracy']) + len(fine_tune_history.history['accuracy']) + 1)
        ax1.plot(epochs_fine, fine_tune_history.history['accuracy'], 'g-', label='Fine-tuning Training Accuracy')
        ax1.plot(epochs_fine, fine_tune_history.history['val_accuracy'], 'm-', label='Fine-tuning Validation Accuracy')
    
    ax1.set_title('Model Accuracy')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Accuracy')
    ax1.legend()
    ax1.grid(True)
    
    ax2.plot(epochs_initial, history.history['loss'], 'b-', label='Training Loss')
    ax2.plot(epochs_initial, history.history['val_loss'], 'r-', label='Validation Loss')
    
    if fine_tune_history:
        epochs_fine = range(len(history.history['loss']) + 1, 
                          len(history.history['loss']) + len(fine_tune_history.history['loss']) + 1)
        ax2.plot(epochs_fine, fine_tune_history.history['loss'], 'g-', label='Fine-tuning Training Loss')
        ax2.plot(epochs_fine, fine_tune_history.history['val_loss'], 'm-', label='Fine-tuning Validation Loss')
    
    ax2.set_title('Model Loss')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Loss')
    ax2.legend()
    ax2.grid(True)
    
    plt.tight_layout()
    plt.savefig('training_history.png')
    plt.show()

plot_training_history(history, fine_tune_history)

model.save('complete_dog_cat.keras')

converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
with open('dog_cat_model.tflite', 'wb') as f:
    f.write(tflite_model)

print("Model training complete and model saved!")

def predict_image(image_path, model):
    img = image.load_img(image_path, target_size=(256, 256))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    
    predictions = model.predict(img_array)
    score = predictions[0][0]
    
    if score > 0.5:
        return f"Dog ({score:.2f})"
    else:
        return f"Cat ({1-score:.2f})"
# Out:
# 2025-05-08 19:48:20.272991: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746733700.518559      31 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746733700.590157      31 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Found 20000 files belonging to 2 classes.
# Using 16000 files for training.
# I0000 00:00:1746733734.990078      31 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Found 20000 files belonging to 2 classes.
# Using 4000 files for validation.
# Found 5000 files.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Phase 1: Training with frozen base model...
# Epoch 1/15
# I0000 00:00:1746733809.661581     100 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.5907 - auc: 0.6209 - loss: 0.7821 - precision: 0.5974 - recall: 0.5746
# Epoch 1: val_accuracy improved from -inf to 0.68475, saving model to best_dog_cat_model_resnet.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 93s 76ms/step - accuracy: 0.5907 - auc: 0.6210 - loss: 0.7820 - precision: 0.5974 - recall: 0.5746 - val_accuracy: 0.6848 - val_auc: 0.7274 - val_loss: 0.7959 - val_precision: 0.6926 - val_recall: 0.6834
# Epoch 2/15
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6360 - auc: 0.6889 - loss: 0.6402 - precision: 0.6480 - recall: 0.6074
# Epoch 2: val_accuracy improved from 0.68475 to 0.74800, saving model to best_dog_cat_model_resnet.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 74s 74ms/step - accuracy: 0.6360 - auc: 0.6889 - loss: 0.6402 - precision: 0.6480 - recall: 0.6074 - val_accuracy: 0.7480 - val_auc: 0.8154 - val_loss: 0.5928 - val_precision: 0.7355 - val_recall: 0.7876
# Epoch 3/15
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6560 - auc: 0.7161 - loss: 0.6169 - precision: 0.6732 - recall: 0.6164
# Epoch 3: val_accuracy did not improve from 0.74800
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 72s 72ms/step - accuracy: 0.6561 - auc: 0.7161 - loss: 0.6169 - precision: 0.6732 - recall: 0.6164 - val_accuracy: 0.7410 - val_auc: 0.8233 - val_loss: 0.6138 - val_precision: 0.7088 - val_recall: 0.8328
# Epoch 4/15
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6637 - auc: 0.7290 - loss: 0.6048 - precision: 0.6862 - recall: 0.6127
# Epoch 4: val_accuracy improved from 0.74800 to 0.75325, saving model to best_dog_cat_model_resnet.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 73s 73ms/step - accuracy: 0.6638 - auc: 0.7290 - loss: 0.6048 - precision: 0.6862 - recall: 0.6127 - val_accuracy: 0.7533 - val_auc: 0.8432 - val_loss: 0.5477 - val_precision: 0.7161 - val_recall: 0.8530
# Epoch 5/15
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6748 - auc: 0.7336 - loss: 0.6000 - precision: 0.6991 - recall: 0.6223
# Epoch 5: val_accuracy improved from 0.75325 to 0.76950, saving model to best_dog_cat_model_resnet.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 73s 73ms/step - accuracy: 0.6748 - auc: 0.7336 - loss: 0.6000 - precision: 0.6991 - recall: 0.6223 - val_accuracy: 0.7695 - val_auc: 0.8484 - val_loss: 0.5402 - val_precision: 0.7409 - val_recall: 0.8407
# Epoch 6/15
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6799 - auc: 0.7416 - loss: 0.5955 - precision: 0.7049 - recall: 0.6271
# Epoch 6: val_accuracy did not improve from 0.76950
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 72s 72ms/step - accuracy: 0.6799 - auc: 0.7416 - loss: 0.5955 - precision: 0.7048 - recall: 0.6271 - val_accuracy: 0.7655 - val_auc: 0.8440 - val_loss: 0.5445 - val_precision: 0.7420 - val_recall: 0.8260
# Epoch 7/15
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6799 - auc: 0.7463 - loss: 0.5914 - precision: 0.7023 - recall: 0.6323
# Epoch 7: val_accuracy improved from 0.76950 to 0.77000, saving model to best_dog_cat_model_resnet.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 73s 73ms/step - accuracy: 0.6799 - auc: 0.7463 - loss: 0.5914 - precision: 0.7023 - recall: 0.6323 - val_accuracy: 0.7700 - val_auc: 0.8492 - val_loss: 0.5524 - val_precision: 0.7493 - val_recall: 0.8230
# Epoch 8/15
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6898 - auc: 0.7543 - loss: 0.5839 - precision: 0.7128 - recall: 0.6431
# Epoch 8: val_accuracy did not improve from 0.77000
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 72s 72ms/step - accuracy: 0.6898 - auc: 0.7543 - loss: 0.5839 - precision: 0.7128 - recall: 0.6431 - val_accuracy: 0.7655 - val_auc: 0.8491 - val_loss: 0.5586 - val_precision: 0.7368 - val_recall: 0.8382
# Epoch 9/15
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6810 - auc: 0.7523 - loss: 0.5857 - precision: 0.7056 - recall: 0.6294
# Epoch 9: val_accuracy did not improve from 0.77000
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 73s 73ms/step - accuracy: 0.6811 - auc: 0.7523 - loss: 0.5857 - precision: 0.7056 - recall: 0.6294 - val_accuracy: 0.7610 - val_auc: 0.8436 - val_loss: 0.5752 - val_precision: 0.7370 - val_recall: 0.8240
# Epoch 10/15
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6864 - auc: 0.7563 - loss: 0.5831 - precision: 0.7083 - recall: 0.6414
# Epoch 10: val_accuracy did not improve from 0.77000
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 72s 72ms/step - accuracy: 0.6864 - auc: 0.7563 - loss: 0.5831 - precision: 0.7083 - recall: 0.6414 - val_accuracy: 0.7577 - val_auc: 0.8514 - val_loss: 0.5678 - val_precision: 0.7150 - val_recall: 0.8707
# Epoch 11/15
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6925 - auc: 0.7610 - loss: 0.5792 - precision: 0.7141 - recall: 0.6498
# Epoch 11: val_accuracy did not improve from 0.77000
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 72s 72ms/step - accuracy: 0.6925 - auc: 0.7610 - loss: 0.5792 - precision: 0.7141 - recall: 0.6498 - val_accuracy: 0.7650 - val_auc: 0.8558 - val_loss: 0.5595 - val_precision: 0.7249 - val_recall: 0.8668
# Epoch 12/15
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6892 - auc: 0.7618 - loss: 0.5767 - precision: 0.7112 - recall: 0.6443
# Epoch 12: val_accuracy did not improve from 0.77000
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 72s 72ms/step - accuracy: 0.6892 - auc: 0.7618 - loss: 0.5767 - precision: 0.7112 - recall: 0.6443 - val_accuracy: 0.7595 - val_auc: 0.8547 - val_loss: 0.5703 - val_precision: 0.7134 - val_recall: 0.8810
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Phase 2: Fine-tuning the model...
# Epoch 1/10
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6820 - auc: 0.7507 - loss: 0.5874 - precision: 0.7232 - recall: 0.5971
# Epoch 1: val_accuracy did not improve from 0.77000
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 87s 74ms/step - accuracy: 0.6820 - auc: 0.7507 - loss: 0.5874 - precision: 0.7232 - recall: 0.5971 - val_accuracy: 0.7638 - val_auc: 0.8508 - val_loss: 0.5540 - val_precision: 0.7225 - val_recall: 0.8692
# Epoch 2/10
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6756 - auc: 0.7438 - loss: 0.5921 - precision: 0.7029 - recall: 0.6169
# Epoch 2: val_accuracy did not improve from 0.77000
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 71s 71ms/step - accuracy: 0.6757 - auc: 0.7438 - loss: 0.5921 - precision: 0.7029 - recall: 0.6169 - val_accuracy: 0.7580 - val_auc: 0.8486 - val_loss: 0.5763 - val_precision: 0.7146 - val_recall: 0.8727
# Epoch 3/10
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6847 - auc: 0.7499 - loss: 0.5882 - precision: 0.7135 - recall: 0.6247
# Epoch 3: val_accuracy did not improve from 0.77000
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 72s 72ms/step - accuracy: 0.6847 - auc: 0.7499 - loss: 0.5882 - precision: 0.7135 - recall: 0.6247 - val_accuracy: 0.7538 - val_auc: 0.8504 - val_loss: 0.5682 - val_precision: 0.7079 - val_recall: 0.8781
# Epoch 4/10
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6767 - auc: 0.7456 - loss: 0.5916 - precision: 0.7031 - recall: 0.6200
# Epoch 4: val_accuracy did not improve from 0.77000
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 73s 73ms/step - accuracy: 0.6767 - auc: 0.7456 - loss: 0.5916 - precision: 0.7031 - recall: 0.6200 - val_accuracy: 0.7570 - val_auc: 0.8501 - val_loss: 0.5638 - val_precision: 0.7138 - val_recall: 0.8717
# Epoch 5/10
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6810 - auc: 0.7475 - loss: 0.5887 - precision: 0.7065 - recall: 0.6270
# Epoch 5: val_accuracy did not improve from 0.77000
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 72s 72ms/step - accuracy: 0.6810 - auc: 0.7475 - loss: 0.5887 - precision: 0.7065 - recall: 0.6270 - val_accuracy: 0.7545 - val_auc: 0.8493 - val_loss: 0.5702 - val_precision: 0.7087 - val_recall: 0.8781
# Epoch 6/10
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6889 - auc: 0.7570 - loss: 0.5831 - precision: 0.7146 - recall: 0.6363
# Epoch 6: val_accuracy did not improve from 0.77000
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 72s 72ms/step - accuracy: 0.6889 - auc: 0.7570 - loss: 0.5831 - precision: 0.7146 - recall: 0.6363 - val_accuracy: 0.7508 - val_auc: 0.8501 - val_loss: 0.5765 - val_precision: 0.7020 - val_recall: 0.8859
# Epoch 7/10
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6809 - auc: 0.7509 - loss: 0.5864 - precision: 0.7070 - recall: 0.6259
# Epoch 7: val_accuracy did not improve from 0.77000
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 72s 72ms/step - accuracy: 0.6809 - auc: 0.7509 - loss: 0.5864 - precision: 0.7070 - recall: 0.6259 - val_accuracy: 0.7542 - val_auc: 0.8507 - val_loss: 0.5696 - val_precision: 0.7093 - val_recall: 0.8756
# Epoch 7: early stopping
# Restoring model weights from the end of the best epoch: 1.
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 14s 55ms/step - accuracy: 0.7570 - auc: 0.8448 - loss: 0.5717 - precision: 0.7175 - recall: 0.8647
# Final Validation Loss: 0.5540
# Final Validation Accuracy: 0.7638
# Final Validation AUC: 0.8508
# Final Validation Precision: 0.7225
# Final Validation Recall: 0.8692
# Saved artifact at '/tmp/tmpxr4x5npa'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name='keras_tensor_175')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   140198071874192: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   140198071874768: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   140198071871888: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   140198471614736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198471616080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198471615312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198471615888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198471614928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198471615696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198471618576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198471620880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198471621840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198471621264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198471622032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198471620304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198471621456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198471624144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198471624528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198471623760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198471622416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198471624336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198471625296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198471626448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198471616656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198471617808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198471618192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198471615504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198471617040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198471618000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198471627024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198471626064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198471627216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198471623184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198471627984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198471629136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198471629712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198471627600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198525273488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198524500880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198471625680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198471630480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198472204944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198472204560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198471629904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198471628368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198472205520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198472206672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198472207056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198472205136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198472205904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198472206864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198472206288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198472209168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198472209552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198472208784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198472207440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198472209360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198472207824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198472211664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198472212048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198472211280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198472209936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198472211856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198472212816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198472213968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198472214352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198472212432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198472213200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198472214160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198472217424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198472218576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198472218960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198472217040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198472217808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198472218768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198472219728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198472219344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473925648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473925264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198472220112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473925072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473926032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473927184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198472215120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198472216272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198472216656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198472214736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198472215504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198472216464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473927568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473925456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473926416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473927376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473928336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473929488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473929872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473927952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473928720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473929680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473930640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473931792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473932176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473930256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473931024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473931984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473932944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473934096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473934480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473932560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473933328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473934288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473935248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473936400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473936784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473934864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473935632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473936592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473937552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473938704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473939088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473937168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473937936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473938896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473939856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473939472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473335440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473335056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473924688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473940240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473336016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473337168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473337552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473335632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473336400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473337360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473338320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473339472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473339856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473337936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473338704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473339664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473340624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473341776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473342160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473340240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473341008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473341968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473345232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473346384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473346768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473344848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473345616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473346576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473347536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473348688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473349072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473347152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473347920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473348880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473349840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473349456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473342928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473344080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473344464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473342544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473343312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473344272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072533072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072534032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473334864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198473350992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072533840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072535184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072535568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072533264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072534416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072535376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072536336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072537488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072537872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072535952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072536720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072537680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072538640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072539792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072540176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072538256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072539024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072539984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072540944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072542096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072542480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072540560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072541328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072542288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072543248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072544400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072544784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072542864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072543632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072544592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072545552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072546704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072547088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072545168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072545936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072546896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072547856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072548816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072549008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072976016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072533456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072549200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072976208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072977360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072977744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072975440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072976592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072977552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072978512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072979664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072980048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072978128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072978896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072979856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072980816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072981968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072982352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072980432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072981200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072982160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072983120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072984272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072984656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072982736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072983504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072984464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072985424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072986576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072986960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072985040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072985808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072986768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072987728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072988880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072989264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072987344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072988112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072989072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072990032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072991184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072975632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071402576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072990416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198072991376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071402768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071404304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071404688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071403536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071403344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071404496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071407760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071408912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071409296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071407376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071408144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071409104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071410064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071411216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071411600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071409680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071410448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071411408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071412368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071413520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071405456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071406608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071406992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071405072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071405840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071406800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071413904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071411984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071412752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071413712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071414672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071415824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071416208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071414288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071415056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071416016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071416976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071418128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071403152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071418512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071417360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071418320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071861712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071862864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071863248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071862480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071862288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071863056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071864016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071865168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071865552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071863632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071864400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071865360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071866320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071867472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071867856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071865936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071866704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071867664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071868624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071869776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071870160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071868240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071869008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071869968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071872464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071874000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071874384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071874960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071872272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071876880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071874576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071877264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071876304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198071877072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198070436688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198070437840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198070438032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140198070438608: TensorSpec(shape=(), dtype=tf.resource, name=None)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1746735247.991343      31 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1746735247.991386      31 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# I0000 00:00:1746735248.157515      31 mlir_graph_optimization_pass.cc:401] MLIR V1 optimization pass is not enabled
# Model training complete and model saved!
